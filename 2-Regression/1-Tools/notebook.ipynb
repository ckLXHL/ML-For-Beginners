# %% [markdown]
# # 2.1 Regression tools

# %%
from sklearn import linear_model, model_selection, datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187235 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990842 -0.01764613]

# %%
X3 = X[:, np.newaxis, 2]
print(X3.shape)
# Out:
# (442, 1)

# %%
X2 = X[:, np.newaxis, 2]
print(X2.shape)
# Out:
# (442, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X2, y, test_size=0.33)
print(X_train.shape)
# Out:
# (296, 1)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, c='black')
plt.plot(X_test, y_pred, c='blue', linewidth=3)

# %%
data_ori = datasets.load_diabetes(as_frame=True)

# %%
data_ori.frame.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
plt.scatter(data_ori.frame['bp'], data_ori.target)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(data_ori.frame, data_ori.target, test_size=0.33)
print(X_train.shape)
print(y_train.shape)
# Out:
# (296, 11)
# (296,)

# %%
model2 = linear_model.LinearRegression()
model2.fit(X_train[['bmi']], y_train)
y_pred = model2.predict(X_test[['bmi']])
plt.scatter(X_test['bmi'], y_test, c='green')
plt.plot(X_test['bmi'], y_pred, c='red')
